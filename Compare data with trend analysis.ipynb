# %%
import pandas as pd
import matplotlib.pyplot as plt
from Altcoin.altcoin.coinData import CoinData
from TickTocTest.ticktoctest.tickToc import getDBdata
# %matplotlib inline

# %% [markdown]
# ### Compare top 5 Altcoins from ticktocDB

# %%
btc = CoinData('btc', getDBdata)
eth = CoinData('eth', getDBdata)
xrp = CoinData('xrp', getDBdata)
bch = CoinData('bch', getDBdata)
eos = CoinData('eos', getDBdata)

# %%
start = '2018-06-01'
btc.plot(start=start, title='Bitcoin')

# %%
btc.trendPlot(start)

# %%
eth.plot(start, title='Ethereum')

# %%
eth.trendPlot(start)

# %%
xrp.plot(start=start, title='Ripple')

# %%
xrp.trendPlot(start)

# %%
bch.plot(start, title='Bitcoin Cash')

# %%
bch.trendPlot(start)

# %%
eos.plot(start, title='Eosio')

# %%
eos.trendPlot(start)
